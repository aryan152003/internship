# %%
# !pip install folium
# Out:
# ...
#    ---------------------------------------- 0.0/108.4 kB ? eta -:--:--
#    ---------------------------------------- 0.0/108.4 kB ? eta -:--:--
#    -------------- ------------------------ 41.0/108.4 kB 653.6 kB/s eta 0:00:01
#    ---------------------------------------- 108.4/108.4 kB 1.3 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import folium

# %%
df = pd.read_csv(r'D:\internship\job_descriptions.csv')

# %%
df.head(5)
# Out:
#              Job Id     Experience Qualifications Salary Range    location  \
# 0  1089843540111562  5 to 15 Years         M.Tech    $59K-$99K     Douglas
# 1   398454096642776  2 to 12 Years            BCA   $56K-$116K    Ashgabat
# 2   481640072963533  0 to 12 Years            PhD   $61K-$104K       Macao
# 3   688192671473044  4 to 11 Years            PhD    $65K-$91K  Porto-Novo
# 4   117057806156508  1 to 12 Years            MBA    $64K-$87K    Santiago
#
#             Country  latitude  longitude  Work Type  Company Size  ...  \
# 0       Isle of Man   54.2361    -4.5481     Intern         26801  ...
# 1      Turkmenistan   38.9697    59.5563     Intern        100340  ...
# 2  Macao SAR, China   22.1987   113.5439  Temporary         84525  ...
# 3             Benin    9.3077     2.3158  Full-Time        129896  ...
# 4             Chile  -35.6751   -71.5429     Intern         53944  ...
#
#                  Contact                     Job Title  \
# ...

# %%
african_countries = [
    "Algeria", "Angola", "Benin", "Botswana", "Burkina Faso", "Burundi", 
    "Cabo Verde", "Cameroon", "Central African Republic", "Chad", "Comoros", 
    "Congo", "Democratic Republic of the Congo", "Djibouti", "Egypt", 
    "Equatorial Guinea", "Eritrea", "Eswatini", "Ethiopia", "Gabon", 
    "Gambia", "Ghana", "Guinea", "Guinea-Bissau", "Ivory Coast", "Kenya", 
    "Lesotho", "Liberia", "Libya", "Madagascar", "Malawi", "Mali", 
    "Mauritania", "Mauritius", "Morocco", "Mozambique", "Namibia", "Niger", 
    "Nigeria", "Rwanda", "Sao Tome and Principe", "Senegal", "Seychelles", 
    "Sierra Leone", "Somalia", "South Africa", "South Sudan", "Sudan", 
    "Tanzania", "Togo", "Tunisia", "Uganda", "Zambia", "Zimbabwe"
]
df = df[~df['Country'].isin(african_countries)]
filtered_df = df[
    (df['Qualifications'].isin(['B.Tech', 'M.Tech', 'PhD'])) &
    (df['Work Type'] == 'Full time') &
    (df['Job Title'].str.startswith('D')) &
    (df['Preference'] == 'Male') &
    (df['Company Size'] > 80000) &
    (df['Contact'].str.startswith('A')) &
    (df['Job Portal'] == 'Indeed')
]

# %%
if not filtered_df.empty:
    company_job_count = filtered_df['Company'].value_counts().head(10)

    plt.figure(figsize=(10, 6))
    company_job_count.plot(kind='bar', color='orange')
    plt.title('Top Companies by Job Title Starting with "D" (Male Preference)')
    plt.xlabel('Company')
    plt.ylabel('Number of Job Postings')
    plt.xticks(rotation=45)
    plt.show()
    m = folium.Map(location=[0, 0], zoom_start=2)
    for idx, row in filtered_df.iterrows():
        folium.Marker(
            location=[row['latitude'], row['longitude']],
            popup=f"Company: {row['company_name']}\nJob Title: {row['job_title']}\nLocation: {row['latitude']}, {row['longitude']}",
            tooltip="Click to see the location"
        ).add_to(m)
    m.save('job_map.html')
else:
    print("The filtered DataFrame is empty. No data to display.")
# Out:
# The filtered DataFrame is empty. No data to display.
